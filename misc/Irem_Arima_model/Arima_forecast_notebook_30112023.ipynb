# %%
from ARIMA_forecast_method import ArimaModel
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
traindf = pd.read_csv('/Users/iremaltiner/Desktop/ErdosProject/Bootcamp Project/train-val-test/ordered_train_set.csv'
                      ,parse_dates=['time'])
testdf = pd.read_csv('/Users/iremaltiner/Desktop/ErdosProject/Bootcamp Project/train-val-test/full_ordered_test_set.csv'
                     ,parse_dates=['time'])

# %%
model = ArimaModel(traindf,testdf)

# %%
#Trains the arima model

model.train()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           38     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.32901D+00    |proj g|=  2.13479D-02
#  This problem is unconstrained.
# At iterate    5    f=  3.32853D+00    |proj g|=  5.82595D-03
#
# At iterate   10    f=  3.32640D+00    |proj g|=  2.39378D-02
#
# At iterate   15    f=  3.32416D+00    |proj g|=  1.05848D-02
#
# At iterate   20    f=  3.32217D+00    |proj g|=  7.74641D-03
#
# At iterate   25    f=  3.32143D+00    |proj g|=  1.19399D-02
#
# At iterate   30    f=  3.31880D+00    |proj g|=  1.27156D-02
#
# At iterate   35    f=  3.31740D+00    |proj g|=  4.31049D-03
#
# At iterate   40    f=  3.31701D+00    |proj g|=  6.87697D-03
#
# At iterate   45    f=  3.31680D+00    |proj g|=  4.09097D-03
#
# At iterate   50    f=  3.31670D+00    |proj g|=  3.19931D-03
#
# At iterate   55    f=  3.31668D+00    |proj g|=  2.31185D-03
#
# ...

# %%
#In this model, each day is predicted separately. What it means that, for each day, the model has access to
#the true values of the previous day. 
#The model has order (24, 1, 7), meaning that to predict one hour of a day, the model uses the previous 24 hours.
#It uses the predicted value of previous hour's price if the previous price is on the same day 
#as the current price we are predicting.
#The following code gives predictions of each day as a dataframe. 

model.get_preds()
# Out:
# /Users/iremaltiner/Desktop/ErdosProject/Bootcamp Project/ARIMA_forecast_method.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.predictions[f'Day {i+1} fcast'] = pd.concat([forecasts, ser])
# /Users/iremaltiner/Desktop/ErdosProject/Bootcamp Project/ARIMA_forecast_method.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.predictions[f'Day {i+1} fcast'] = pd.concat([forecasts, ser])
# ...

# %%
#RMSE along the all test set.

model.RMSE
# Out:
# 20.572269564063635

# %%
model.sample_plot()

# %%
model.predictions.to_csv('Forecast_model_preds_30112023.csv')

# %%
model.arima.save('ArimaForecast30112023')
